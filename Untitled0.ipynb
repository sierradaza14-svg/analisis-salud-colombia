# %% [markdown]
# Escogi este dataser de consultas de medicina general del Ministerio de Salud de Colombia ya que me parece bien interesante y creo que podria relacionarse con mi carrera, en especial por que en otra materia estoy haciendo un proyecto relaciondo con la telemedicina y hacer un analisis de datos de medicina general me sirve para continuar con este proyecto que ademas se relaciona con la optimizacion de procesos.

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-42046d76-ba32-44eb-89b2-1fc549c19214" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42046d76-ba32-44eb-89b2-1fc549c19214">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('ConsultasMedicinaGral.csv', encoding='latin-1')

df.head()
# Out:
#                                        Nom_Categoria Fecha_Factura    Cups  \
# 0  05        - Consultas de medicina general elec...    2020-02-27  890201
# 1  05        - Consultas de medicina general elec...    2020-02-27  890301
# 2  05        - Consultas de medicina general elec...    2020-02-27  890201
# 3  05        - Consultas de medicina general elec...    2020-02-27  890201
# 4  05        - Consultas de medicina general elec...    2020-02-27  890201
#
#                                    Nom_Procedimiento  \
# 0  CONSULTA DE PRIMERA VEZ POR MEDICINA GENERAL R...
# 1  CONSULTA DE CONTROL O DE SEGUIMIENTO POR MEDIC...
# 2  CONSULTA DE PRIMERA VEZ POR MEDICINA GENERAL  ...
# 3  CONSULTA DE PRIMERA VEZ POR MEDICINA GENERAL R...
# 4  CONSULTA DE PRIMERA VEZ POR MEDICINA GENERAL R...
#
#                                              Regimen  \
# 0  Subsidiado                                    ...
# 1  Subsidiado                                    ...
# ...

# %% [markdown]
# El dataset contiene informacion sobre categoria de la consulta, tipo de procedimiento, regimen del paciente y la IPS donde se realizo la consulta

# %%
df.shape
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84329 entries, 0 to 84328
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Nom_Categoria      84329 non-null  object
#  1   Fecha_Factura      84329 non-null  object
#  2   Cups               84329 non-null  int64
#  3   Nom_Procedimiento  84329 non-null  object
#  4   Regimen            84329 non-null  object
#  5   IPS                84329 non-null  object
#  6   Cantidad           84329 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 4.5+ MB

# %%
df.isnull().sum()
# Out:
# Nom_Categoria        0
# Fecha_Factura        0
# Cups                 0
# Nom_Procedimiento    0
# Regimen              0
# IPS                  0
# Cantidad             0
# dtype: int64

# %% [markdown]
# no se encontraron valores nulos en el dataset

# %%
df.duplicated().sum()
# Out:
# np.int64(78106)

# %%
df.describe()
# Out:
#                 Cups      Cantidad
# count   84329.000000  84329.000000
# mean   890230.656797      1.003688
# std        45.678859      0.060617
# min    890115.000000      1.000000
# 25%    890201.000000      1.000000
# 50%    890201.000000      1.000000
# 75%    890301.000000      1.000000
# max    890301.000000      2.000000

# %%
df_limpio = df.copy()

# %%
# Eliminar duplicados
df_limpio = df_limpio.drop_duplicates()
print(f'🔁 Duplicados eliminados: {filas_antes - len(df_limpio)}')
# Out:
# 🔁 Duplicados eliminados: 78106

# %%
# Borrar columnas que tengan mas de la mitad de nulos
cols_antes = df_limpio.shape[1]
df_limpio = df_limpio.dropna(thresh=int(0.5 * len(df_limpio)), axis=1)
print(f'🗑️ Columnas eliminadas por exceso de nulos: {cols_antes - df_limpio.shape[1]}')
# Out:
# 🗑️ Columnas eliminadas por exceso de nulos: 0

# %%
# Llenar los nulos con la mediana para no dejar vacios
for col in df_limpio.select_dtypes(include=np.number).columns:
    if df_limpio[col].isnull().sum() > 0:
        df_limpio[col].fillna(df_limpio[col].median(), inplace=True)
        print(f'🔧 "{col}": nulos reemplazados con mediana')

# %%
# Llenar nulos de texto con 'N/A'
for col in df_limpio.select_dtypes(include='object').columns:
    if df_limpio[col].isnull().sum() > 0:
        df_limpio[col].fillna('N/A', inplace=True)
        print(f'🔧 "{col}": nulos reemplazados con "N/A"')
